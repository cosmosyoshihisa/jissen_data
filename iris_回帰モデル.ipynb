# %% [markdown]
# iris_dataを使って解析

# %%
data(iris)
PL <- iris$Petal.Length
PW <- iris$Petal.Width
SL <- iris$Sepal.Length
SW <- iris$Sepal.Width
SP <- iris$Species
#Sepal:がく片、Petal:花びら

# %% [markdown]
# 単回帰

# %%
lsr1 <- lm(PW~PL)

# %%
summary(lsr1)
plot(PL,PW)
abline(lsr1)
# Out:
# Call:
# lm(formula = PW ~ PL)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.56515 -0.12358 -0.01898  0.13288  0.64272
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.363076   0.039762  -9.131  4.7e-16 ***
# PL           0.415755   0.009582  43.387  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.2065 on 148 degrees of freedom
# Multiple R-squared:  0.9271,	Adjusted R-squared:  0.9266
# F-statistic:  1882 on 1 and 148 DF,  p-value: < 2.2e-16
# plot without title

# %% [markdown]
# 重回帰分析

# %%
lsr2 <- lm(PW~PL+SP)

# %%
summary(lsr2)
plot(PL,PW)
#abline(lsr2)
# Out:
# Call:
# lm(formula = PW ~ PL + SP)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.63706 -0.07779 -0.01218  0.09829  0.47814
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.09083    0.05639  -1.611    0.109
# PL            0.23039    0.03443   6.691 4.41e-10 ***
# SPversicolor  0.43537    0.10282   4.234 4.04e-05 ***
# SPvirginica   0.83771    0.14533   5.764 4.71e-08 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.1796 on 146 degrees of freedom
# Multiple R-squared:  0.9456,	Adjusted R-squared:  0.9445
# F-statistic: 845.5 on 3 and 146 DF,  p-value: < 2.2e-16
# plot without title

# %%
a0 <-coef(lsr2)[1]
a0
# Out:
# (Intercept)
# -0.09082938

# %%
a1 <- coef(lsr2)[1]+coef(lsr2)[3]
a1
# Out:
# (Intercept)
#   0.3445409

# %%
a2<- coef(lsr2)[1] +coef(lsr2)[4]
b <- coef(lsr2)[2]

# %%
plot( PL,PW, type ="n")
points( PL[SP=="setosa"],PW[SP=="setosa"],col="blue")
points( PL[SP=="versicolor"], PW[SP=="versicolor"],col="red")
points( PL[SP=="virginica"],PW[SP=="virginica"],col="green3")
abline(a=a0, b, col="blue")
abline(a=a1, b, col="red")
abline(a=a2, b, col="green3")
abline(lsr1)
# Out:
# plot without title

# %%
summary(iris)
# Out:
#   Sepal.Length    Sepal.Width     Petal.Length    Petal.Width
#  Min.   :4.300   Min.   :2.000   Min.   :1.000   Min.   :0.100
#  1st Qu.:5.100   1st Qu.:2.800   1st Qu.:1.600   1st Qu.:0.300
#  Median :5.800   Median :3.000   Median :4.350   Median :1.300
#  Mean   :5.843   Mean   :3.057   Mean   :3.758   Mean   :1.199
#  3rd Qu.:6.400   3rd Qu.:3.300   3rd Qu.:5.100   3rd Qu.:1.800
#  Max.   :7.900   Max.   :4.400   Max.   :6.900   Max.   :2.500
#        Species
#  setosa    :50
#  versicolor:50
#  virginica :50

# %%
lsr3 <- lm(PW~PL*SP)
summary(lsr3)
# Out:
# Call:
# lm(formula = PW ~ PL * SP)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.6337 -0.0744 -0.0134  0.0866  0.4503
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)     -0.04822    0.21472  -0.225 0.822627
# PL               0.20125    0.14586   1.380 0.169813
# SPversicolor    -0.03607    0.31538  -0.114 0.909109
# SPvirginica      1.18425    0.33417   3.544 0.000532 ***
# PL:SPversicolor  0.12981    0.15550   0.835 0.405230
# PL:SPvirginica  -0.04095    0.15291  -0.268 0.789244
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.1773 on 144 degrees of freedom
# Multiple R-squared:  0.9477,	Adjusted R-squared:  0.9459
# F-statistic: 521.9 on 5 and 144 DF,  p-value: < 2.2e-16

# %%
c0 <- coef(lsr3)[1]
c1 <- coef(lsr3)[1] +coef(lsr3)[3]
c2 <- coef(lsr3)[1]+ coef(lsr3)[4]

d0 <- coef(lsr3)[2]
d1 <- coef(lsr3)[2]+ coef(lsr3)[5]
d2 <- coef(lsr3)[2]+coef(lsr3)[6]

plot( PL,PW, type ="n")
points( PL[SP=="setosa"],PW[SP=="setosa"],col="blue")
points( PL[SP=="versicolor"], PW[SP=="versicolor"],col="red")
points( PL[SP=="virginica"],PW[SP=="virginica"],col="green3")
abline(a=c0, b= d0, col="blue")
abline(a=c1, b= d1, col="red")
abline(a=c2, b= d2, col="green3")
abline(lsr1)
# Out:
# plot without title

# %%
lsr12 <- lm(PW~PL+SW+SL+SP) 
summary(lsr12)
# Out:
# Call:
# lm(formula = PW ~ PL + SW + SL + SP)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.59239 -0.08288 -0.01349  0.08773  0.45239
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.47314    0.17659  -2.679  0.00824 **
# PL            0.24220    0.04884   4.959 1.97e-06 ***
# SW            0.24220    0.04776   5.072 1.20e-06 ***
# SL           -0.09293    0.04458  -2.084  0.03889 *
# SPversicolor  0.64811    0.12314   5.263 5.04e-07 ***
# SPvirginica   1.04637    0.16548   6.323 3.03e-09 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.1666 on 144 degrees of freedom
# Multiple R-squared:  0.9538,	Adjusted R-squared:  0.9522
# F-statistic: 594.9 on 5 and 144 DF,  p-value: < 2.2e-16

# %% [markdown]
# 課題：自分たちで回帰モデルを作る！！

# %%
lsr4 <- lm(PW~PL*SP+SW)
summary(lsr4)
# Out:
# Call:
# lm(formula = PW ~ PL * SP + SW)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.55903 -0.09220 -0.00648  0.08204  0.45965
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)     -0.60269    0.23816  -2.531   0.0125 *
# PL               0.12607    0.13840   0.911   0.3639
# SPversicolor     0.29059    0.30609   0.949   0.3440
# SPvirginica      1.41450    0.31897   4.435 1.83e-05 ***
# SW               0.19381    0.04399   4.405 2.06e-05 ***
# PL:SPversicolor  0.13244    0.14643   0.904   0.3673
# PL:SPvirginica  -0.01119    0.14414  -0.078   0.9382
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.167 on 143 degrees of freedom
# Multiple R-squared:  0.954,	Adjusted R-squared:  0.952
# F-statistic: 493.7 on 6 and 143 DF,  p-value: < 2.2e-16

# %%
lsr5 <- lm(PW~PL*SP+SL)
summary(lsr5)
# Out:
# Call:
# lm(formula = PW ~ PL * SP + SL)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.62927 -0.07760 -0.01068  0.08902  0.45057
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     -0.083014   0.284399  -0.292  0.77079
# PL               0.196767   0.148289   1.327  0.18665
# SPversicolor    -0.021157   0.326292  -0.065  0.94839
# SPvirginica      1.210294   0.362947   3.335  0.00109 **
# SL               0.008258   0.044066   0.187  0.85161
# PL:SPversicolor  0.127447   0.156534   0.814  0.41690
# PL:SPvirginica  -0.044693   0.154721  -0.289  0.77311
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.1779 on 143 degrees of freedom
# Multiple R-squared:  0.9477,	Adjusted R-squared:  0.9455
# F-statistic:   432 on 6 and 143 DF,  p-value: < 2.2e-16

# %%
lsr6 <- lm(PW~PL*SP+SW+SL)
summary(lsr6)#*SPに対して+SPもしくは+SL単体よりも+SP+SLの方が相関が良い
#SPは+よりも*が相関が良い
# Out:
# Call:
# lm(formula = PW ~ PL * SP + SW + SL)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.58940 -0.07638 -0.00951  0.07966  0.43389
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)     -0.35750    0.27074  -1.320 0.188816
# PL               0.15689    0.13825   1.135 0.258341
# SPversicolor     0.20283    0.30720   0.660 0.510152
# SPvirginica      1.19502    0.33777   3.538 0.000545 ***
# SW               0.23152    0.04814   4.809 3.82e-06 ***
# SL              -0.08381    0.04526  -1.852 0.066129 .
# PL:SPversicolor  0.15692    0.14580   1.076 0.283635
# PL:SPvirginica   0.03260    0.14488   0.225 0.822301
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.1656 on 142 degrees of freedom
# Multiple R-squared:  0.955,	Adjusted R-squared:  0.9528
# F-statistic: 430.9 on 7 and 142 DF,  p-value: < 2.2e-16

# %%
lsr64 <- lm(PW~PL*SP*SW)
summary(lsr64)
# Out:
# Call:
# lm(formula = PW ~ PL * SP * SW)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.47266 -0.06821 -0.01030  0.08447  0.47864
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)          0.8262     2.0461   0.404  0.68700
# PL                  -0.5362     1.4390  -0.373  0.71002
# SPversicolor        -0.7170     2.8775  -0.249  0.80361
# SPvirginica         -5.1638     2.7599  -1.871  0.06346 .
# SW                  -0.2425     0.5866  -0.413  0.67998
# PL:SPversicolor      0.6886     1.5154   0.454  0.65027
# PL:SPvirginica       1.4275     1.4743   0.968  0.33459
# PL:SW                0.2060     0.4111   0.501  0.61708
# SPversicolor:SW      0.2810     0.9718   0.289  0.77287
# SPvirginica:SW       2.3138     0.8682   2.665  0.00861 **
# PL:SPversicolor:SW  -0.1672     0.4486  -0.373  0.70984
# PL:SPvirginica:SW   -0.4922     0.4255  -1.157  0.24938
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# ...

# %%
lsr65 <- lm(PW~PL*SP*SW+SL)
summary(lsr65)
# Out:
# Call:
# lm(formula = PW ~ PL * SP * SW + SL)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.50037 -0.06801 -0.00462  0.08025  0.45839
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         0.73895    2.03918   0.362  0.71763
# PL                 -0.35291    1.43913  -0.245  0.80665
# SPversicolor       -0.51467    2.86995  -0.179  0.85794
# SPvirginica        -5.22721    2.74966  -1.901  0.05940 .
# SW                 -0.13268    0.58930  -0.225  0.82220
# SL                 -0.06372    0.04439  -1.436  0.15342
# PL:SPversicolor     0.55682    1.51240   0.368  0.71331
# PL:SPvirginica      1.33685    1.47001   0.909  0.36473
# PL:SW               0.15862    0.41087   0.386  0.70005
# SPversicolor:SW     0.19460    0.96995   0.201  0.84128
# SPvirginica:SW      2.28654    0.86505   2.643  0.00917 **
# PL:SPversicolor:SW -0.12161    0.44798  -0.271  0.78644
# PL:SPvirginica:SW  -0.45620    0.42463  -1.074  0.28455
# ---
# ...

# %%
lsr66 <- lm(PW~PL*SP*SL+SW)
summary(lsr66)
# Out:
# Call:
# lm(formula = PW ~ PL * SP * SL + SW)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.61653 -0.06913 -0.00399  0.07949  0.45903
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)         0.445226   2.582770   0.172    0.863
# PL                 -0.271161   1.848400  -0.147    0.884
# SPversicolor        1.414416   3.541647   0.399    0.690
# SPvirginica        -3.767435   3.397558  -1.109    0.269
# SL                 -0.254011   0.519826  -0.489    0.626
# SW                  0.234616   0.052031   4.509 1.38e-05 ***
# PL:SPversicolor     0.114976   1.931738   0.060    0.953
# PL:SPvirginica      1.195872   1.898555   0.630    0.530
# PL:SL               0.090599   0.370420   0.245    0.807
# SPversicolor:SL    -0.189684   0.680696  -0.279    0.781
# SPvirginica:SL      0.793908   0.610834   1.300    0.196
# PL:SPversicolor:SL -0.007526   0.383534  -0.020    0.984
# ...

# %%
extractAIC(lsr64)
extractAIC(lsr65)
extractAIC(lsr66)
# Out:
# [1]   12.0000 -541.4726
# [1]   13.0000 -541.7121
# [1]   13.0000 -527.1465

# %%
lsr7 <- lm(PW~PL*SP*SW*SL)
summary(lsr7)
#(訂正)+SLから*SLにするとAICの値が大きくなる→*SLよりも+SLの方がいい？
# Out:
# Call:
# lm(formula = PW ~ PL * SP * SW * SL)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.46875 -0.07345 -0.00146  0.07475  0.52145
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)             1.21978   26.29403   0.046   0.9631
# PL                     -0.57510   19.04822  -0.030   0.9760
# SPversicolor            9.36170   35.23324   0.266   0.7909
# SPvirginica            53.96504   32.73021   1.649   0.1017
# SW                     -0.24586    7.35204  -0.033   0.9734
# SL                     -0.10751    5.39175  -0.020   0.9841
# PL:SPversicolor        -2.56628   19.88379  -0.129   0.8975
# PL:SPvirginica        -10.35030   19.38391  -0.534   0.5943
# PL:SW                   0.08295    5.34035   0.016   0.9876
# SPversicolor:SW        -2.17453   11.54826  -0.188   0.8509
# SPvirginica:SW        -18.86367   10.19326  -1.851   0.0666 .
# PL:SL                   0.04569    3.87113   0.012   0.9906
# ...

# %%
extractAIC(lsr7)
# Out:
# [1]   24.0000 -537.4705

# %%
SW_2 <- SW^2#がく片の幅を2倍

# %%
lsr8 <- lm(PW~PL*SP*SW_2*SL)
summary(lsr8)#SWよりSW_2での相関の方が良かった
# Out:
# Call:
# lm(formula = PW ~ PL * SP * SW_2 * SL)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.46325 -0.07330 -0.00158  0.07671  0.52628
#
# Coefficients:
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)              0.7294246 13.5543397   0.054   0.9572
# PL                      -0.4034023  9.7645201  -0.041   0.9671
# SPversicolor             5.5414376 18.0087176   0.308   0.7588
# SPvirginica             26.2098287 16.6122818   1.578   0.1171
# SW_2                    -0.0244409  1.0464057  -0.023   0.9814
# SL                      -0.0866441  2.7911414  -0.031   0.9753
# PL:SPversicolor         -1.2383398 10.1814519  -0.122   0.9034
# PL:SPvirginica          -4.7327279  9.9280150  -0.477   0.6344
# PL:SW_2                  0.0060449  0.7574331   0.008   0.9936
# SPversicolor:SW_2       -0.2473914  1.9881772  -0.124   0.9012
# SPvirginica:SW_2        -3.1670219  1.6197888  -1.955   0.0528 .
# ...

# %%
lsr81 <- lm(PW~PL*SP*SW_2+SL)
summary(lsr81)
# Out:
# Call:
# lm(formula = PW ~ PL * SP * SW_2 + SL)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.50185 -0.06813 -0.00294  0.08191  0.46565
#
# Coefficients:
#                      Estimate Std. Error t value Pr(>|t|)
# (Intercept)           0.40543    1.05447   0.384  0.70121
# PL                   -0.00424    0.74296  -0.006  0.99545
# SPversicolor         -0.15199    1.46998  -0.103  0.91780
# SPvirginica          -2.12571    1.39760  -1.521  0.13057
# SW_2                 -0.01021    0.08630  -0.118  0.90597
# SL                   -0.06523    0.04434  -1.471  0.14357
# PL:SPversicolor       0.27051    0.77798   0.348  0.72860
# PL:SPvirginica        0.61951    0.75524   0.820  0.41348
# PL:SW_2               0.01688    0.05969   0.283  0.77776
# SPversicolor:SW_2     0.03126    0.17082   0.183  0.85507
# SPvirginica:SW_2      0.42204    0.13682   3.085  0.00246 **
# PL:SPversicolor:SW_2 -0.01205    0.06860  -0.176  0.86080
# ...

# %%
extractAIC(lsr8)
# Out:
# [1]   24.0000 -538.5572

# %%
extractAIC(lsr81)#やはり+SLの方がよさそう。
# Out:
# [1]   13.0000 -543.0744

# %%
SL_2 <- SL^2

# %%
lsr9 <- lm(PW~PL*SP*SW*SL_2)
summary(lsr9)#SLよりSL_2での相関の方が良かった(ほんのちょっと)
# Out:
# Call:
# lm(formula = PW ~ PL * SP * SW * SL_2)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.46832 -0.07300 -0.00164  0.07306  0.51893
#
# Coefficients:
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)              1.091e+00  1.313e+01   0.083   0.9339
# PL                      -5.851e-01  9.537e+00  -0.061   0.9512
# SPversicolor             4.519e+00  1.750e+01   0.258   0.7966
# SPvirginica              2.857e+01  1.685e+01   1.695   0.0925 .
# SW                      -2.689e-01  3.682e+00  -0.073   0.9419
# SL_2                    -1.551e-02  5.478e-01  -0.028   0.9775
# PL:SPversicolor         -9.815e-01  9.953e+00  -0.099   0.9216
# PL:SPvirginica          -5.183e+00  9.741e+00  -0.532   0.5956
# PL:SW                    1.574e-01  2.680e+00   0.059   0.9533
# SPversicolor:SW         -1.035e+00  5.737e+00  -0.180   0.8571
# SPvirginica:SW          -9.690e+00  5.279e+00  -1.836   0.0688 .
# ...

# %%
lsr10 <- lm(PW~PL*SP*SW_2*SL_2)
summary(lsr10)
# Out:
# Call:
# lm(formula = PW ~ PL * SP * SW_2 * SL_2)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.46252 -0.07306 -0.00097  0.07330  0.52360
#
# Coefficients:
#                             Estimate Std. Error t value Pr(>|t|)
# (Intercept)                5.548e-01  6.766e+00   0.082   0.9348
# PL                        -2.708e-01  4.885e+00  -0.055   0.9559
# SPversicolor               2.769e+00  8.938e+00   0.310   0.7573
# SPvirginica                1.422e+01  8.571e+00   1.660   0.0995 .
# SW_2                      -3.014e-02  5.259e-01  -0.057   0.9544
# SL_2                      -9.994e-03  2.846e-01  -0.035   0.9720
# PL:SPversicolor           -4.777e-01  5.093e+00  -0.094   0.9254
# PL:SPvirginica            -2.413e+00  4.986e+00  -0.484   0.6293
# PL:SW_2                    1.745e-02  3.811e-01   0.046   0.9635
# SPversicolor:SW_2         -1.226e-01  9.875e-01  -0.124   0.9014
# SPvirginica:SW_2          -1.613e+00  8.455e-01  -1.908   0.0587 .
# ...

# %%
SA = SL*SW #SA:Sepal Area
SA
# Out:
#   [1] 17.85 14.70 15.04 14.26 18.00 21.06 15.64 17.00 12.76 15.19 19.98 16.32
#  [13] 14.40 12.90 23.20 25.08 21.06 17.85 21.66 19.38 18.36 18.87 16.56 16.83
#  [25] 16.32 15.00 17.00 18.20 17.68 15.04 14.88 18.36 21.32 23.10 15.19 16.00
#  [37] 19.25 17.64 13.20 17.34 17.50 10.35 14.08 17.50 19.38 14.40 19.38 14.72
#  [49] 19.61 16.50 22.40 20.48 21.39 12.65 18.20 15.96 20.79 11.76 19.14 14.04
#  [61] 10.00 17.70 13.20 17.69 16.24 20.77 16.80 15.66 13.64 14.00 18.88 17.08
#  [73] 15.75 17.08 18.56 19.80 19.04 20.10 17.40 14.82 13.20 13.20 15.66 16.20
#  [85] 16.20 20.40 20.77 14.49 16.80 13.75 14.30 18.30 15.08 11.50 15.12 17.10
#  [97] 16.53 17.98 12.75 15.96 20.79 15.66 21.30 18.27 19.50 22.80 12.25 21.17
# [109] 16.75 25.92 20.80 17.28 20.40 14.25 16.24 20.48 19.50 29.26 20.02 13.20
# [121] 22.08 15.68 21.56 17.01 22.11 23.04 17.36 18.30 17.92 21.60 20.72 30.02
# [133] 17.92 17.64 15.86 23.10 21.42 19.84 18.00 21.39 20.77 21.39 15.66 21.76
# ...

# %%
lsr11 <- lm(PW~PL*SP*SA)
summary(lsr11)#面積は考えない方が良さそう（特徴量減るから？？）
# Out:
# Call:
# lm(formula = PW ~ PL * SP * SA)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.52877 -0.08153 -0.01455  0.10534  0.52340
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         0.53256    1.30232   0.409   0.6832
# PL                 -0.30111    0.92229  -0.326   0.7446
# SPversicolor       -0.34762    1.79485  -0.194   0.8467
# SPvirginica        -2.15079    1.77668  -1.211   0.2281
# SA                 -0.03124    0.07451  -0.419   0.6757
# PL:SPversicolor     0.50241    0.96711   0.520   0.6042
# PL:SPvirginica      0.80824    0.94768   0.853   0.3952
# PL:SA               0.02734    0.05241   0.522   0.6027
# SPversicolor:SA     0.03278    0.11252   0.291   0.7712
# SPvirginica:SA      0.22300    0.09683   2.303   0.0228 *
# PL:SPversicolor:SA -0.02373    0.05578  -0.425   0.6712
# PL:SPvirginica:SA  -0.05397    0.05348  -1.009   0.3146
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# ...

# %%
lsr13 <- lm(PW~PL*SP*SA*SL)
summary(lsr13)
# Out:
# Call:
# lm(formula = PW ~ PL * SP * SA * SL)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.45990 -0.06698 -0.00148  0.07732  0.50525
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)            2.021527  15.212950   0.133    0.894
# PL                    -1.443309  11.060996  -0.130    0.896
# SPversicolor           5.413155  19.874847   0.272    0.786
# SPvirginica           17.928661  18.153270   0.988    0.325
# SA                    -0.144142   0.836316  -0.172    0.863
# SL                    -0.238699   3.191742  -0.075    0.941
# PL:SPversicolor       -0.491908  11.470805  -0.043    0.966
# PL:SPvirginica        -2.453995  11.251349  -0.218    0.828
# PL:SA                  0.102522   0.609158   0.168    0.867
# SPversicolor:SA        0.068929   1.198931   0.057    0.954
# SPvirginica:SA        -0.590792   1.032451  -0.572    0.568
# PL:SL                  0.198451   2.294730   0.086    0.931
# ...

# %%
lsr14 <- lm(PW~PL*SP*SA*SW)
summary(lsr14)
# Out:
# Call:
# lm(formula = PW ~ PL * SP * SA * SW)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.46695 -0.07476  0.00038  0.08315  0.48971
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)             4.430806  11.334899   0.391    0.697
# PL                     -2.979016   8.254307  -0.361    0.719
# SPversicolor          -13.449942  15.453862  -0.870    0.386
# SPvirginica            10.797572  14.705998   0.734    0.464
# SA                     -0.289378   0.795502  -0.364    0.717
# SW                     -1.043804   3.200296  -0.326    0.745
# PL:SPversicolor         5.871560   8.650771   0.679    0.499
# PL:SPvirginica          0.400138   8.429022   0.047    0.962
# PL:SA                   0.210765   0.560605   0.376    0.708
# SPversicolor:SA         0.166633   1.113698   0.150    0.881
# SPvirginica:SA         -0.624673   0.928030  -0.673    0.502
# PL:SW                   0.692743   2.344708   0.295    0.768
# ...

# %%
lsr15 <- lm(PW~PL*SP*SA*SW*SL)
summary(lsr15)#面積という特徴量をさらに増やすことで少し相関が上がった
# Out:
# Call:
# lm(formula = PW ~ PL * SP * SA * SW * SL)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.44237 -0.06270 -0.01263  0.08271  0.45607
#
# Coefficients: (6 not defined because of singularities)
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)               -8.76219  165.92768  -0.053   0.9580
# PL                         6.17599  116.23457   0.053   0.9577
# SPversicolor             -25.22572  219.91261  -0.115   0.9089
# SPvirginica               -2.03148  199.72598  -0.010   0.9919
# SA                       -13.38081   12.87646  -1.039   0.3010
# SW                        16.55643   52.49190   0.315   0.7531
# SL                         8.94396   36.23976   0.247   0.8055
# PL:SPversicolor            9.75100  121.39793   0.080   0.9361
# PL:SPvirginica            -1.51215  118.04577  -0.013   0.9898
# PL:SA                     10.57957    9.44414   1.120   0.2651
# SPversicolor:SA           16.65454   17.84124   0.933   0.3527
# ...

# %%
SL_10<- SL^10
SW_10<- SW^10

# %%
lsr16 <- lm(PW~PL*SP*SL_100*SW_100)
summary(lsr16)#がく片の幅と長さを誇張しても意味ない
# Out:
# Error in eval(predvars, data, env):  オブジェクト 'SL_100' がありません
# Traceback:
#
# 1. lm(PW ~ PL * SP * SL_100 * SW_100)
# 2. eval(mf, parent.frame())
# 3. eval(mf, parent.frame())
# 4. stats::model.frame(formula = PW ~ PL * SP * SL_100 * SW_100,
#  .     drop.unused.levels = TRUE)
# 5. model.frame.default(formula = PW ~ PL * SP * SL_100 * SW_100,
#  .     drop.unused.levels = TRUE)
# 6. eval(predvars, data, env)
# 7. eval(predvars, data, env)

# %%
lsr17 <- lm(PW~PL*SP*SA*SW_2*SL_2)
summary(lsr17)#面積という特徴量をさらに増やすことで少し相関が上がった
# Out:
# Call:
# lm(formula = PW ~ PL * SP * SA * SW_2 * SL_2)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.43859 -0.06769 -0.00268  0.06314  0.46359
#
# Coefficients:
#                                Estimate Std. Error t value Pr(>|t|)
# (Intercept)                   12.065501  41.291538   0.292    0.771
# PL                           -10.243653  29.013737  -0.353    0.725
# SPversicolor                 -59.993566  59.486831  -1.009    0.316
# SPvirginica                  -21.838602  50.809484  -0.430    0.668
# SA                           -16.426370  29.952583  -0.548    0.585
# SW_2                          11.125980  22.564128   0.493    0.623
# SL_2                           4.699849  10.491837   0.448    0.655
# PL:SPversicolor               24.612422  30.922952   0.796    0.428
# PL:SPvirginica                13.279372  29.600299   0.449    0.655
# PL:SA                         11.108448  22.226169   0.500    0.618
# ...

# %%
extractAIC(lsr17)
# Out:
# [1]   48.0000 -519.1571

# %%
extractAIC(lsr1)
# Out:
# [1]    2.0000 -471.2727

# %%
extractAIC(lsr15)
# Out:
# [1]   42.0000 -525.9482

# %%
lsr18 <- lm(PW~PL*SP*SA*SW*SL*SL_2*SW_2*SL_10*SW_10)
summary(lsr18)#面積という特徴量をさらに増やすことで少し相関が上がった
# Out:
# Call:
# lm(formula = PW ~ PL * SP * SA * SW * SL * SL_2 * SW_2 * SL_10 *
#     SW_10)
#
# Residuals:
#    Min     1Q Median     3Q    Max
#   -0.2    0.0    0.0    0.0    0.2
#
# Coefficients: (626 not defined because of singularities)
#                                                  Estimate Std. Error t value
# (Intercept)                                     4.269e+06  3.716e+07   0.115
# PL                                              3.050e+06  5.323e+06   0.573
# SPversicolor                                   -7.846e+06  8.210e+06  -0.956
# SPvirginica                                    -9.897e+06  1.787e+07  -0.554
# SA                                              2.647e+06  1.345e+07   0.197
# SW                                             -1.493e+07  2.918e+07  -0.512
# SL                                              3.112e+06  2.303e+07   0.135
# SL_2                                           -1.732e+06  5.581e+06  -0.310
# ...

# %%
lsr18_step <- step(lsr18)
# Out:
# Start:  AIC=-721.02
# PW ~ PL * SP * SA * SW * SL * SL_2 * SW_2 * SL_10 * SW_10
#
#
# Step:  AIC=-721.02
# PW ~ PL + SP + SA + SW + SL + SL_2 + SW_2 + SL_10 + SW_10 + PL:SP +
#     PL:SA + SP:SA + PL:SW + SP:SW + SA:SW + PL:SL + SP:SL + SA:SL +
#     SW:SL + PL:SL_2 + SP:SL_2 + SA:SL_2 + SW:SL_2 + SL:SL_2 +
#     PL:SW_2 + SP:SW_2 + SA:SW_2 + SW:SW_2 + SL:SW_2 + SL_2:SW_2 +
#     PL:SL_10 + SP:SL_10 + SA:SL_10 + SW:SL_10 + SL:SL_10 + SL_2:SL_10 +
#     SW_2:SL_10 + PL:SW_10 + SP:SW_10 + SA:SW_10 + SW:SW_10 +
#     SL:SW_10 + SL_2:SW_10 + SW_2:SW_10 + SL_10:SW_10 + PL:SP:SA +
#     PL:SP:SW + PL:SA:SW + SP:SA:SW + PL:SP:SL + PL:SA:SL + SP:SA:SL +
#     PL:SW:SL + SP:SW:SL + SA:SW:SL + PL:SP:SL_2 + PL:SA:SL_2 +
#     SP:SA:SL_2 + PL:SW:SL_2 + SP:SW:SL_2 + SA:SW:SL_2 + PL:SL:SL_2 +
#     SP:SL:SL_2 + SA:SL:SL_2 + SW:SL:SL_2 + PL:SP:SW_2 + PL:SA:SW_2 +
#     SP:SA:SW_2 + PL:SW:SW_2 + SP:SW:SW_2 + SA:SW:SW_2 + PL:SL:SW_2 +
# ...

# %%
lsr19 <- lm(PW~PL*SP*SW*SL*SA*SW_2*SL_2)
summary(lsr19)#面積という特徴量をさらに増やすことで少し相関が上がった
# Out:
# Call:
# lm(formula = PW ~ PL * SP * SW * SL * SA * SW_2 * SL_2)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.232225 -0.017646  0.000067  0.027434  0.243260
#
# Coefficients: (80 not defined because of singularities)
#                                      Estimate Std. Error t value Pr(>|t|)
# (Intercept)                         2.803e+05  6.106e+05   0.459  0.64885
# PL                                 -5.511e+05  3.099e+05  -1.778  0.08339 .
# SPversicolor                        1.514e+06  1.370e+06   1.105  0.27618
# SPvirginica                         1.376e+06  1.397e+06   0.986  0.33057
# SW                                 -1.410e+05  4.613e+05  -0.306  0.76155
# SL                                 -1.148e+05  4.910e+05  -0.234  0.81637
# SA                                  3.560e+04  3.924e+05   0.091  0.92820
# SW_2                                1.623e+04  1.215e+05   0.134  0.89441
# ...

# %%
lsr19_step <-　step(lsr19)
# Out:
# Start:  AIC=-560.52
# PW ~ PL * SP * SW * SL * SA * SW_2 * SL_2
#
#                            Df Sum of Sq     RSS     AIC
# - PL:SP:SW:SL:SA:SW_2:SL_2  1 0.0032241 0.80616 -561.92
# <none>                                  0.80294 -560.52
#
# Step:  AIC=-561.92
# PW ~ PL + SP + SW + SL + SA + SW_2 + SL_2 + PL:SP + PL:SW + SP:SW +
#     PL:SL + SP:SL + SW:SL + PL:SA + SP:SA + SW:SA + SL:SA + PL:SW_2 +
#     SP:SW_2 + SW:SW_2 + SL:SW_2 + SA:SW_2 + PL:SL_2 + SP:SL_2 +
#     SW:SL_2 + SL:SL_2 + SA:SL_2 + SW_2:SL_2 + PL:SP:SW + PL:SP:SL +
#     PL:SW:SL + SP:SW:SL + PL:SP:SA + PL:SW:SA + SP:SW:SA + PL:SL:SA +
#     SP:SL:SA + SW:SL:SA + PL:SP:SW_2 + PL:SW:SW_2 + SP:SW:SW_2 +
#     PL:SL:SW_2 + SP:SL:SW_2 + SW:SL:SW_2 + PL:SA:SW_2 + SP:SA:SW_2 +
#     SW:SA:SW_2 + SL:SA:SW_2 + PL:SP:SL_2 + PL:SW:SL_2 + SP:SW:SL_2 +
#     PL:SL:SL_2 + SP:SL:SL_2 + SW:SL:SL_2 + PL:SA:SL_2 + SP:SA:SL_2 +
#     SW:SA:SL_2 + SL:SA:SL_2 + PL:SW_2:SL_2 + SP:SW_2:SL_2 + SW:SW_2:SL_2 +
# ...

# %%
extractAIC(lsr19_step)
# Out:
# [1]  111.0000 -558.9811

# %%
extractAIC(lsr19)
# Out:
# [1]  112.0000 -560.5166

# %%
SA_1_2 <- SA^(1/2)

# %%
lsr21 <- lm(PW~PL*SP*SW*SL*SL_2*SW_2*SA_1_2)
summary(lsr21)
# Out:
# Call:
# lm(formula = PW ~ PL * SP * SW * SL * SL_2 * SW_2 * SA_1_2)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.297902 -0.022864 -0.000037  0.032222  0.219306
#
# Coefficients: (80 not defined because of singularities)
#                                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)                             2.818e+05  2.362e+05   1.193   0.2403
# PL                                     -3.383e+05  2.367e+05  -1.430   0.1610
# SPversicolor                            2.762e+05  5.731e+05   0.482   0.6327
# SPvirginica                             3.649e+05  4.436e+05   0.823   0.4158
# SW                                     -1.603e+05  2.030e+05  -0.789   0.4347
# SL                                      1.173e+05  1.360e+05   0.862   0.3939
# SL_2                                   -1.993e+05  7.900e+04  -2.523   0.0160
# SW_2                                   -4.176e+05  1.967e+05  -2.123   0.0403
# ...
